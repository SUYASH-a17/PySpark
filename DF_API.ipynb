# %%
https://data.cityofchicago.org/resource/ijzp-q8t2.csv
# Out:
#   File "<ipython-input-4-bf51b7c8b11d>", line 1
#     https://data.cityofchicago.org/resource/ijzp-q8t2.csv
#           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# Load the data directly from the URL into a Pandas DataFrame
url = "https://data.cityofchicago.org/resource/ijzp-q8t2.csv"
df = pd.read_csv(url)

# Display the first few rows of the DataFrame (optional)
display(df.head())
# Out:
#          id case_number                     date               block  iucr  \
# 0  13741457    JJ140358  2025-02-05T00:00:00.000  114XX S OAKLEY AVE  0810
# 1  13744875    JJ144610  2025-02-05T00:00:00.000   089XX S THROOP ST  1150
# 2  13743702    JJ142257  2025-02-05T00:00:00.000   121XX S BISHOP ST  0810
# 3  13742078    JJ139658  2025-02-05T00:00:00.000     0000X E 57TH ST  1020
# 4  13740468    JJ139072  2025-02-05T00:00:00.000     004XX E 41ST ST  0710
#
#          primary_type               description  \
# 0               THEFT                 OVER $500
# 1  DECEPTIVE PRACTICE         CREDIT CARD FRAUD
# 2               THEFT                 OVER $500
# 3               ARSON                   BY FIRE
# 4               THEFT  THEFT FROM MOTOR VEHICLE
#
#                     location_description  arrest  domestic  ...  ward  \
# 0              NURSING / RETIREMENT HOME   False     False  ...    19
# 1                              RESIDENCE   False     False  ...    21
# 2                                 STREET   False     False  ...    21
# 3                                 STREET   False     False  ...    20
# 4  POLICE FACILITY / VEHICLE PARKING LOT   False     False  ...     3
#
#    community_area  fbi_code  x_coordinate y_coordinate  year  \
# 0              75        06     1163013.0    1828741.0  2025
# 1              73        11     1169228.0    1845462.0  2025
# 2              53        06     1168863.0    1824169.0  2025
# 3              40        09     1178019.0    1867257.0  2025
# 4              38        06     1179773.0    1877905.0  2025
#
#                 updated_on   latitude  longitude  \
# 0  2025-02-12T15:41:15.000  41.685703 -87.678876
# 1  2025-02-12T15:41:15.000  41.731456 -87.655642
# 2  2025-02-12T15:41:15.000  41.673032 -87.657592
# 3  2025-02-12T15:41:15.000  41.791069 -87.622778
# 4  2025-02-12T15:41:15.000  41.820248 -87.616021
#
#                                location
# 0  \n,  \n(41.685702753, -87.678875923)
# 1  \n,  \n(41.731455968, -87.655642365)
# 2  \n,  \n(41.673032455, -87.657591553)
# 3  \n,  \n(41.791069429, -87.622778206)
# 4  \n,  \n(41.820248497, -87.616020877)
#
# [5 rows x 22 columns]
